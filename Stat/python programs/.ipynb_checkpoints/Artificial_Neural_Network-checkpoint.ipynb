# %% [markdown]
# ## Artificial Neural Networks
#
# An ANN is based on a collection of connected units or nodes called artificial neurons, which loosely model the neurons in a biological brain. Each connection, like the synapses in a biological brain, can transmit a signal from one artificial neuron to another. An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.
#
#
# ![alt text](https://askabiologist.asu.edu/sites/default/files/resources/articles/neuron_anatomy.jpg)
#
# A Diagram of Neuron Cell

# %% [markdown]
# ### Perceptron
#
# In machine learning, the perceptron is an algorithm for supervised learning of binary classifiers. A binary classifier is a function which can decide whether or not an input, represented by a vector of numbers, belongs to some specific class. It is a type of linear classifier, i.e. a classification algorithm that makes its predictions based on a linear predictor function combining a set of weights with the feature vector.
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*n6sJ4yZQzwKL9wnF5wnVNg.png)

# %% [markdown]
# Lets see a sample implementation of Neural Network.

# %%
import numpy as np
import scipy as sp
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
# input and output layer dimension
class Config:
  nn_input_dim = 2
  nn_output_dim = 2
  
	# Gradient descent parameters
  epsilon = 0.01 # same as alpha
  reg_lambda = 0.01 # penalty term

# %%
def draw_visualization(X, Y, model):
  plot_decision_boundary(lambda x:predict(model,x), X, Y)

# %%
def plot_decision_boundary(pred_func, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)
    plt.show()

# %%
# Calculate loss of the neural model
def calculate_loss(model, X, Y):
  data_size = len(X)
  W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']

    # Forward propagation to calculate our predictions	
  z1 = X.dot(W1) + b1
  a1 = np.tanh(z1)
  z2 = a1.dot(W2) + b2
  
  exp_scores = np.exp(z2)
  probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
	# Calculating the loss
  corect_logprobs = -np.log(probs[range(data_size), Y])
  data_loss = np.sum(corect_logprobs)

	# Add regularization term to loss
  data_loss += Config.reg_lambda/2 * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
  return 1./data_size * data_loss

# %%
def predict(model, x):
	W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
	# forward propagation
	z1 = x.dot(W1) + b1
	a1 = np.tanh(z1)
	z2 = a1.dot(W2) + b2
	output_scores = np.exp(z2)
	probs = output_scores / np.sum(output_scores, axis=1, keepdims=True)
	return np.argmax(probs, axis=1)

# %%
def build_training_model(X, Y, nn_hidden_dim, num_passes = 10000, print_loss = True):

	data_size = len(X)
	np.random.seed(0)
	W1 = np.random.randn(Config.nn_input_dim, nn_hidden_dim) / np.sqrt(Config.nn_input_dim) # Xavier's Intialization
	b1 = np.zeros((1, nn_hidden_dim))
	W2 = np.random.randn(nn_hidden_dim, Config.nn_output_dim) / np.sqrt(nn_hidden_dim)
	b2 = np.zeros((1, Config.nn_output_dim))
    

	model = {}

	for i in range(0, num_passes):

	    # Forward propagation
	    z1 = X.dot(W1) + b1
	    a1 = np.tanh(z1)
	    z2 = a1.dot(W2) + b2
	    exp_scores = np.exp(z2)
	    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

	    delta3 = probs
	    delta3[range(data_size), Y] -= 1
	    dW2 = (a1.T).dot(delta3)
	    db2 = np.sum(delta3, axis=0, keepdims=True)
	    delta2 = delta3.dot(W2.T) * (1 - np.power(a1, 2))
	    dW1 = np.dot(X.T, delta2)
	    db1 = np.sum(delta2, axis=0)

	    # Add regularization terms (b1 and b2 don't have regularization terms)
	    dW2 += Config.reg_lambda * W2
	    dW1 += Config.reg_lambda * W1

	    # Gradient descent parameter update
	    W1 += -Config.epsilon * dW1
	    b1 += -Config.epsilon * db1
	    W2 += -Config.epsilon * dW2
	    b2 += -Config.epsilon * db2

	    # Assign new parameters to the model
	    model = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}

	    # Optionally print the loss.
	    # This is expensive because it uses the whole dataset, so we don't want to do it too often.
	    if print_loss and i % 500 == 0:
	        print("Loss after iteration %i: %f" % (i, calculate_loss(model, X, Y)))

	return model

# %%
def sample_minibatches(inputs,targets, chunksize, shuffle=True):
    # Provide chunks one by one
    
    assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    for start_idx in range(0, inputs.shape[0] - chunksize + 1, chunksize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + chunksize]
        else:
            excerpt = slice(start_idx, start_idx + chunksize)
        yield inputs[excerpt], targets[excerpt]

# %%
def main():
    
    # generate a random distribution and plot it.
	np.random.seed(0)
	X, Y = datasets.make_moons(1000, noise = 0.2)
	plt.scatter(X[:,0], X[:,1], s=40 , c=Y, cmap = plt.cm.Spectral)
	plt.show()
	batcherator = sample_minibatches(X,Y,100)

	# Train model
	for X_chunk, y_chunk in batcherator:
		model = build_training_model(X_chunk, y_chunk, 25)
 
    # Now make predictions with trained model
    # y_predicted = model.predict(X_test)

	# model = build_training_model(X, Y, 50)
	draw_visualization(X, Y, model)


if __name__ == "__main__":
    main()
# Out:
# Loss after iteration 0: 0.584312
# Loss after iteration 500: 0.028454
# Loss after iteration 1000: 0.018644
# Loss after iteration 1500: 0.015752
# Loss after iteration 2000: 0.014589
# Loss after iteration 2500: 0.014008
# Loss after iteration 3000: 0.013656
# Loss after iteration 3500: 0.013410
# Loss after iteration 4000: 0.013221
# Loss after iteration 4500: 0.013067
# Loss after iteration 5000: 0.012936
# Loss after iteration 5500: 0.012822
# Loss after iteration 6000: 0.012722
# Loss after iteration 6500: 0.012634
# Loss after iteration 7000: 0.012555
# Loss after iteration 7500: 0.012484
# Loss after iteration 8000: 0.012421
# Loss after iteration 8500: 0.012364
# Loss after iteration 9000: 0.012313
# Loss after iteration 9500: 0.012266
# Loss after iteration 0: 0.629010
# Loss after iteration 500: 0.118868
# Loss after iteration 1000: 0.086502
# Loss after iteration 1500: 0.080324
# Loss after iteration 2000: 0.077323
# Loss after iteration 2500: 0.075143
# Loss after iteration 3000: 0.073469
# Loss after iteration 3500: 0.072120
# Loss after iteration 4000: 0.070927
# Loss after iteration 4500: 0.069751
# Loss after iteration 5000: 0.068506
# Loss after iteration 5500: 0.067165
# Loss after iteration 6000: 0.065758
# Loss after iteration 6500: 0.064337
# Loss after iteration 7000: 0.062928
# Loss after iteration 7500: 0.061511
# Loss after iteration 8000: 0.060028
# Loss after iteration 8500: 0.058471
# Loss after iteration 9000: 0.056926
# Loss after iteration 9500: 0.055491
# Loss after iteration 0: 0.600217
# Loss after iteration 500: 0.097895
# Loss after iteration 1000: 0.086399
# Loss after iteration 1500: 0.081239
# Loss after iteration 2000: 0.076690
# Loss after iteration 2500: 0.072108
# Loss after iteration 3000: 0.068556
# Loss after iteration 3500: 0.066030
# Loss after iteration 4000: 0.064207
# Loss after iteration 4500: 0.066455
# Loss after iteration 5000: 0.063012
# Loss after iteration 5500: 0.062346
# Loss after iteration 6000: 0.061813
# Loss after iteration 6500: 0.061368
# Loss after iteration 7000: 0.060993
# Loss after iteration 7500: 0.060669
# Loss after iteration 8000: 0.060365
# Loss after iteration 8500: 0.060057
# Loss after iteration 9000: 0.059749
# Loss after iteration 9500: 0.059447
# Loss after iteration 0: 0.519368
# Loss after iteration 500: 0.051142
# Loss after iteration 1000: 0.031404
# Loss after iteration 1500: 0.024454
# Loss after iteration 2000: 0.021728
# Loss after iteration 2500: 0.020515
# Loss after iteration 3000: 0.019905
# Loss after iteration 3500: 0.019560
# Loss after iteration 4000: 0.019343
# Loss after iteration 4500: 0.019193
# Loss after iteration 5000: 0.019080
# Loss after iteration 5500: 0.018990
# Loss after iteration 6000: 0.018915
# Loss after iteration 6500: 0.018850
# Loss after iteration 7000: 0.018793
# Loss after iteration 7500: 0.018741
# Loss after iteration 8000: 0.018695
# Loss after iteration 8500: 0.018653
# Loss after iteration 9000: 0.018614
# Loss after iteration 9500: 0.018578
# Loss after iteration 0: 0.724104
# Loss after iteration 500: 0.047229
# Loss after iteration 1000: 0.032313
# Loss after iteration 1500: 0.026956
# Loss after iteration 2000: 0.024605
# Loss after iteration 2500: 0.023404
# Loss after iteration 3000: 0.022699
# Loss after iteration 3500: 0.022229
# Loss after iteration 4000: 0.021880
# Loss after iteration 4500: 0.021598
# Loss after iteration 5000: 0.021358
# Loss after iteration 5500: 0.021144
# Loss after iteration 6000: 0.020951
# Loss after iteration 6500: 0.020776
# Loss after iteration 7000: 0.020622
# Loss after iteration 7500: 0.020490
# Loss after iteration 8000: 0.020383
# Loss after iteration 8500: 0.020299
# Loss after iteration 9000: 0.020233
# Loss after iteration 9500: 0.020180
# Loss after iteration 0: 0.552876
# Loss after iteration 500: 0.027029
# Loss after iteration 1000: 0.019427
# Loss after iteration 1500: 0.016745
# Loss after iteration 2000: 0.015435
# Loss after iteration 2500: 0.014711
# Loss after iteration 3000: 0.014272
# Loss after iteration 3500: 0.013982
# Loss after iteration 4000: 0.013776
# Loss after iteration 4500: 0.013620
# Loss after iteration 5000: 0.013496
# Loss after iteration 5500: 0.013394
# Loss after iteration 6000: 0.013307
# Loss after iteration 6500: 0.013232
# Loss after iteration 7000: 0.013166
# Loss after iteration 7500: 0.013107
# Loss after iteration 8000: 0.013054
# Loss after iteration 8500: 0.013006
# Loss after iteration 9000: 0.012962
# Loss after iteration 9500: 0.012923
# Loss after iteration 0: 0.548273
# Loss after iteration 500: 0.081607
# Loss after iteration 1000: 0.059791
# Loss after iteration 1500: 0.047257
# Loss after iteration 2000: 0.041282
# Loss after iteration 2500: 0.038270
# Loss after iteration 3000: 0.036556
# Loss after iteration 3500: 0.035503
# Loss after iteration 4000: 0.034814
# Loss after iteration 4500: 0.034342
# Loss after iteration 5000: 0.034006
# Loss after iteration 5500: 0.033759
# Loss after iteration 6000: 0.033572
# Loss after iteration 6500: 0.033428
# Loss after iteration 7000: 0.033313
# Loss after iteration 7500: 0.033221
# Loss after iteration 8000: 0.033144
# Loss after iteration 8500: 0.033079
# Loss after iteration 9000: 0.033021
# Loss after iteration 9500: 0.032966
# Loss after iteration 0: 0.560105
# Loss after iteration 500: 0.071082
# Loss after iteration 1000: 0.060428
# Loss after iteration 1500: 0.056105
# Loss after iteration 2000: 0.053574
# Loss after iteration 2500: 0.051376
# Loss after iteration 3000: 0.048289
# Loss after iteration 3500: 0.045816
# Loss after iteration 4000: 0.043112
# Loss after iteration 4500: 0.040126
# Loss after iteration 5000: 0.037184
# Loss after iteration 5500: 0.034712
# Loss after iteration 6000: 0.032902
# Loss after iteration 6500: 0.031681
# Loss after iteration 7000: 0.030870
# Loss after iteration 7500: 0.030316
# Loss after iteration 8000: 0.029922
# Loss after iteration 8500: 0.029628
# Loss after iteration 9000: 0.029400
# Loss after iteration 9500: 0.029219
# Loss after iteration 0: 0.371021
# Loss after iteration 500: 0.041199
# Loss after iteration 1000: 0.026278
# Loss after iteration 1500: 0.022931
# Loss after iteration 2000: 0.021352
# Loss after iteration 2500: 0.020334
# Loss after iteration 3000: 0.019568
# Loss after iteration 3500: 0.018946
# Loss after iteration 4000: 0.018419
# Loss after iteration 4500: 0.017963
# Loss after iteration 5000: 0.017566
# Loss after iteration 5500: 0.017216
# Loss after iteration 6000: 0.016908
# Loss after iteration 6500: 0.016636
# Loss after iteration 7000: 0.016395
# Loss after iteration 7500: 0.016181
# Loss after iteration 8000: 0.015991
# Loss after iteration 8500: 0.015822
# Loss after iteration 9000: 0.015671
# Loss after iteration 9500: 0.015536
# Loss after iteration 0: 0.606187
# Loss after iteration 500: 0.105757
# Loss after iteration 1000: 0.098392
# Loss after iteration 1500: 0.095188
# Loss after iteration 2000: 0.092727
# Loss after iteration 2500: 0.090219
# Loss after iteration 3000: 0.087677
# Loss after iteration 3500: 0.085508
# Loss after iteration 4000: 0.083760
# Loss after iteration 4500: 0.082286
# Loss after iteration 5000: 0.080973
# Loss after iteration 5500: 0.079741
# Loss after iteration 6000: 0.078525
# Loss after iteration 6500: 0.077278
# Loss after iteration 7000: 0.078044
# Loss after iteration 7500: 0.076184
# Loss after iteration 8000: 0.075054
# Loss after iteration 8500: 0.073981
# Loss after iteration 9000: 0.073017
# Loss after iteration 9500: 0.072204
